# %% [markdown]
# EVALUATION OF CLUSTERED ONTOLOGY:

# %%
from owlready2 import *
from rdflib import RDFS

# Load ontologies
onto1 = get_ontology("gold_standard_Ontology").load()
onto2 = get_ontology("clustered_ontology1.owl").load()

# Extract classes
classes_onto1 = {str(cls.label[0]).lower(): cls for cls in onto1.classes() if cls.label}
classes_onto2 = {str(cls.label[0]).lower(): cls for cls in onto2.classes() if cls.label}

# Find common classes
common_classes = set()
for label1, cls1 in classes_onto1.items():
    words1 = set(label1.split())
    for label2, cls2 in classes_onto2.items():
        words2 = set(label2.split())
        if words1.issubset(words2):
            if not label1.startswith("measure of"):
                common_classes.add((label1, cls1, cls2))
                break

# Print all common classes and their superclasses
count = 0

for label, cls1, cls2 in common_classes:
    print(f"Common Class: {label}")
    
    superclasses1 = [str(sup.label[0]).lower() for sup in cls1.ancestors() if sup.label]
    superclasses2 = [str(sup.label[0]).lower() for sup in cls2.ancestors() if sup.label]
    count += 1
    
    print(f"Superclasses in Onto1: {', '.join(superclasses1)}")
    print(f"Superclasses in Onto2: {', '.join(superclasses2)}")
    print("----------------------------")

print(count)
# Out:
# Common Class: incidence
# Superclasses in Onto1: measure of concept, incidence, measure of safety
# Superclasses in Onto2: incidence of adverse events, measure of efficacy
# ----------------------------
# Common Class: morbidity
# Superclasses in Onto1: measure of concept, measure of performance status, morbidity
# Superclasses in Onto2: measure of efficacy, overall surgical morbidity
# ----------------------------
# Common Class: total cost comparison
# Superclasses in Onto1: measure of concept, measure of costs, total cost comparison
# Superclasses in Onto2: measure of performance status, total cost comparison
# ----------------------------
# Common Class: nutritional status
# Superclasses in Onto1: measure of concept, nutritional status, measure of nutritional status
# Superclasses in Onto2: measure of patient satisfaction, evaluate nutritional status indicators
# ----------------------------
# Common Class: pain
# Superclasses in Onto1: pain, complications, treatment-related adverse events, measure of concept, measure of safety
# Superclasses in Onto2: measure of efficacy, abdominal pain severity score
# ----------------------------
# Common Class: recurrence-free survival
# Superclasses in Onto1: recurrence, recurrence-free survival, measure of efficacy, measure of concept
# Superclasses in Onto2: recurrence-free time and survival, measure of efficacy
# ----------------------------
# Common Class: treatment response
# Superclasses in Onto1: measure of concept, measure of efficacy, treatment response
# Superclasses in Onto2: measure of performance status, response to treatment by recist criteria
# ----------------------------
# Common Class: progression-free survival
# Superclasses in Onto1: measure of concept, progression-free survival, measure of efficacy
# Superclasses in Onto2: progression-free survival, measure of efficacy
# ----------------------------
# Common Class: mortality
# Superclasses in Onto1: mortality, measure of efficacy, measure of concept, measure of safety
# Superclasses in Onto2: measure of efficacy, mortality
# ----------------------------
# Common Class: complications
# Superclasses in Onto1: measure of safety, measure of concept, complications
# Superclasses in Onto2: measure of efficacy, incidence of post-operative intra-abdominal infectious complications
# ----------------------------
# Common Class: overall response rate
# Superclasses in Onto1: overall response rate, measure of concept, measure of efficacy
# Superclasses in Onto2: measure of performance status, overall response rate
# ----------------------------
# Common Class: hematologic toxicity
# Superclasses in Onto1: toxicity, hematologic toxicity, measure of concept, measure of safety
# Superclasses in Onto2: measure of efficacy, grade of acute hematologic toxicity
# ----------------------------
# Common Class: pathological response rate
# Superclasses in Onto1: measure of concept, measure of efficacy, pathological response rate
# Superclasses in Onto2: pathological response rate, measure of efficacy
# ----------------------------
# Common Class: postoperative complications
# Superclasses in Onto1: postoperative complications, complications, treatment-related adverse events, measure of concept, measure of safety
# Superclasses in Onto2: frequency of patients with postoperative major complications occurring within a certain time after surgery, measure of efficacy
# ----------------------------
# Common Class: pathological response
# Superclasses in Onto1: measure of concept, measure of efficacy, pathological response
# Superclasses in Onto2: pathological response rate, measure of efficacy
# ----------------------------
# Common Class: time to progression
# Superclasses in Onto1: measure of concept, measure of efficacy, time to progression
# Superclasses in Onto2: measure of performance status, time to progression
# ----------------------------
# Common Class: tumor response
# Superclasses in Onto1: measure of concept, tumor response, measure of efficacy
# Superclasses in Onto2: measure of efficacy, confirmed tumor response rate
# ----------------------------
# Common Class: maximum tolerated dose
# Superclasses in Onto1: maximum tolerated dose, measure of concept, measure of safety
# Superclasses in Onto2: measure of efficacy, maximum tolerated dose of lbh589
# ----------------------------
# Common Class: overall survival
# Superclasses in Onto1: measure of concept, measure of efficacy, overall survival
# Superclasses in Onto2: assessment of c677t and a1298c mthfr polymorphisms and overall survival, measure of patient satisfaction
# ----------------------------
# Common Class: disease control rate
# Superclasses in Onto1: measure of concept, measure of efficacy, disease control rate
# Superclasses in Onto2: disease control rate, measure of efficacy
# ----------------------------
# Common Class: objective response rate
# Superclasses in Onto1: measure of concept, measure of efficacy, objective response rate
# Superclasses in Onto2: measure of efficacy, objective tumor response rate
# ----------------------------
# Common Class: surgical morbidity
# Superclasses in Onto1: measure of concept, measure of performance status, surgical morbidity
# Superclasses in Onto2: measure of efficacy, overall surgical morbidity
# ----------------------------
# Common Class: recurrence
# Superclasses in Onto1: measure of concept, recurrence, measure of efficacy
# Superclasses in Onto2: incidence of endoperitoneal recurrence, measure of efficacy
# ----------------------------
# Common Class: toxicity
# Superclasses in Onto1: toxicity, measure of concept, measure of safety
# Superclasses in Onto2: measure of efficacy, grade of acute hematologic toxicity
# ----------------------------
# Common Class: dose-limiting toxicities
# Superclasses in Onto1: measure of concept, measure of safety, dose-limiting toxicities
# Superclasses in Onto2: measure of efficacy, number of participants with dose-limiting toxicities in the five radiation sessions in arm
# ----------------------------
# Common Class: area under curve
# Superclasses in Onto1: measure of concept, measure of performance status, area under curve
# Superclasses in Onto2: measure of performance status, area under the plasma concentration-time curve from time 0 to the time of the last quantifiable concentration
# ----------------------------
# Common Class: adenoma detection rate
# Superclasses in Onto1: measure of concept, measure of efficacy, adenoma detection rate
# Superclasses in Onto2: adenoma detection rate in two different colonoscopies, measure of efficacy
# ----------------------------
# Common Class: blood loss
# Superclasses in Onto1: complications, treatment-related adverse events, measure of concept, blood loss, measure of safety
# Superclasses in Onto2: measure of patient satisfaction, normalized blood loss
# ----------------------------
# Common Class: acute toxicity
# Superclasses in Onto1: toxicity, acute toxicity, measure of concept, measure of safety
# Superclasses in Onto2: measure of efficacy, grade of acute hematologic toxicity
# ----------------------------
# Common Class: overall survival rate
# Superclasses in Onto1: measure of concept, overall survival rate, measure of efficacy
# Superclasses in Onto2: overall survival rate, measure of efficacy
# ----------------------------
# Common Class: radiomics
# Superclasses in Onto1: measure of concept, measure of efficacy, radiomics
# Superclasses in Onto2: development and validation of a deep learning radiomics, measure of efficacy
# ----------------------------
# 31

# %% [markdown]
# This ontology has 15 matching classes with the same superclasses

# %% [markdown]
# EVALUATION OF NON-CLUSTERED ONTOLOGY:

# %%
from owlready2 import *
from rdflib import RDFS

# Load ontologies
onto1 = get_ontology("gold_standard_Ontology").load()
onto2 = get_ontology("non_clustered_ontology2.owl").load()

# Extract classes
classes_onto1 = {str(cls.label[0]).lower(): cls for cls in onto1.classes() if cls.label}
classes_onto2 = {str(cls.label[0]).lower(): cls for cls in onto2.classes() if cls.label}

# Find common classes
common_classes = set()
for label1, cls1 in classes_onto1.items():
    words1 = set(label1.split())
    for label2, cls2 in classes_onto2.items():
        words2 = set(label2.split())
        if words1.issubset(words2):
            if not label1.startswith("measure of"):
                common_classes.add((label1, cls1, cls2))
                break

# Print all common classes and their superclasses
count = 0

for label, cls1, cls2 in common_classes:
    print(f"Common Class: {label}")
    
    superclasses1 = [str(sup.label[0]).lower() for sup in cls1.ancestors() if sup.label]
    superclasses2 = [str(sup.label[0]).lower() for sup in cls2.ancestors() if sup.label]
    count += 1
    
    print(f"Superclasses in Onto1: {', '.join(superclasses1)}")
    print(f"Superclasses in Onto2: {', '.join(superclasses2)}")
    print("----------------------------")

print(count)
# Out:
# Common Class: incidence
# Superclasses in Onto1: measure of concept, incidence, measure of safety
# Superclasses in Onto2: measure of patient satisfaction, incidence of adverse events
# ----------------------------
# Common Class: disease control rate
# Superclasses in Onto1: measure of concept, measure of efficacy, disease control rate
# Superclasses in Onto2: measure of efficacy, disease control rate
# ----------------------------
# Common Class: surgical morbidity
# Superclasses in Onto1: measure of concept, measure of performance status, surgical morbidity
# Superclasses in Onto2: measure of performance status, overall surgical morbidity
# ----------------------------
# Common Class: mortality
# Superclasses in Onto1: mortality, measure of efficacy, measure of concept, measure of safety
# Superclasses in Onto2: mortality, measure of efficacy
# ----------------------------
# Common Class: treatment response
# Superclasses in Onto1: measure of concept, measure of efficacy, treatment response
# Superclasses in Onto2: response to treatment by recist criteria, measure of patient satisfaction
# ----------------------------
# Common Class: complications
# Superclasses in Onto1: measure of safety, measure of concept, complications
# Superclasses in Onto2: measure of patient satisfaction, frequency of patients with postoperative major complications occurring within a certain time after surgery
# ----------------------------
# Common Class: acute toxicity
# Superclasses in Onto1: toxicity, acute toxicity, measure of concept, measure of safety
# Superclasses in Onto2: acute toxicity, measure of patient satisfaction
# ----------------------------
# Common Class: toxicity
# Superclasses in Onto1: toxicity, measure of concept, measure of safety
# Superclasses in Onto2: determine the dose-limiting toxicity, measure of patient satisfaction
# ----------------------------
# Common Class: hematologic toxicity
# Superclasses in Onto1: toxicity, hematologic toxicity, measure of concept, measure of safety
# Superclasses in Onto2: measure of efficacy, grade of acute hematologic toxicity
# ----------------------------
# Common Class: morbidity
# Superclasses in Onto1: measure of concept, measure of performance status, morbidity
# Superclasses in Onto2: measure of performance status, overall surgical morbidity
# ----------------------------
# Common Class: dose-limiting toxicities
# Superclasses in Onto1: measure of concept, measure of safety, dose-limiting toxicities
# Superclasses in Onto2: number of participants with dose-limiting toxicities, measure of efficacy
# ----------------------------
# Common Class: radiomics
# Superclasses in Onto1: measure of concept, measure of efficacy, radiomics
# Superclasses in Onto2: development and validation of a deep learning radiomics, measure of patient satisfaction
# ----------------------------
# Common Class: time to progression
# Superclasses in Onto1: measure of concept, measure of efficacy, time to progression
# Superclasses in Onto2: time to progression, measure of efficacy
# ----------------------------
# Common Class: maximum tolerated dose
# Superclasses in Onto1: maximum tolerated dose, measure of concept, measure of safety
# Superclasses in Onto2: measure of efficacy, determine the maximum tolerated dose of e7070 in combination with irinotecan in patients with gastrointestinal tract
# ----------------------------
# Common Class: recurrence
# Superclasses in Onto1: measure of concept, recurrence, measure of efficacy
# Superclasses in Onto2: measure of efficacy, incidence of endoperitoneal recurrence
# ----------------------------
# Common Class: nutritional status
# Superclasses in Onto1: measure of concept, nutritional status, measure of nutritional status
# Superclasses in Onto2: evaluate nutritional status indicators, measure of patient satisfaction
# ----------------------------
# Common Class: adenoma detection rate
# Superclasses in Onto1: measure of concept, measure of efficacy, adenoma detection rate
# Superclasses in Onto2: measure of efficacy, adenoma detection rate in two different colonoscopies
# ----------------------------
# Common Class: tumor response
# Superclasses in Onto1: measure of concept, tumor response, measure of efficacy
# Superclasses in Onto2: measure of efficacy, confirmed tumor response rate
# ----------------------------
# Common Class: overall survival rate
# Superclasses in Onto1: measure of concept, overall survival rate, measure of efficacy
# Superclasses in Onto2: overall survival rate, measure of efficacy
# ----------------------------
# Common Class: recurrence-free survival
# Superclasses in Onto1: recurrence, recurrence-free survival, measure of efficacy, measure of concept
# Superclasses in Onto2: measure of patient satisfaction, recurrence-free time and survival
# ----------------------------
# Common Class: progression-free survival
# Superclasses in Onto1: measure of concept, progression-free survival, measure of efficacy
# Superclasses in Onto2: measure of patient satisfaction, progression-free survival
# ----------------------------
# Common Class: overall survival
# Superclasses in Onto1: measure of concept, measure of efficacy, overall survival
# Superclasses in Onto2: assessment of c677t and a1298c mthfr polymorphisms and overall survival, measure of patient satisfaction
# ----------------------------
# Common Class: area under curve
# Superclasses in Onto1: measure of concept, measure of performance status, area under curve
# Superclasses in Onto2: area under the plasma concentration-time curve from time 0 to the time of the last quantifiable concentration, measure of efficacy
# ----------------------------
# Common Class: pain
# Superclasses in Onto1: pain, complications, treatment-related adverse events, measure of concept, measure of safety
# Superclasses in Onto2: measure of efficacy, abdominal pain severity score
# ----------------------------
# Common Class: pathological response rate
# Superclasses in Onto1: measure of concept, measure of efficacy, pathological response rate
# Superclasses in Onto2: measure of efficacy, pathological complete response rate
# ----------------------------
# Common Class: overall response rate
# Superclasses in Onto1: overall response rate, measure of concept, measure of efficacy
# Superclasses in Onto2: measure of efficacy, overall response rate
# ----------------------------
# Common Class: pathological response
# Superclasses in Onto1: measure of concept, measure of efficacy, pathological response
# Superclasses in Onto2: measure of efficacy, pathological complete response rate
# ----------------------------
# Common Class: postoperative complications
# Superclasses in Onto1: postoperative complications, complications, treatment-related adverse events, measure of concept, measure of safety
# Superclasses in Onto2: measure of patient satisfaction, frequency of patients with postoperative major complications occurring within a certain time after surgery
# ----------------------------
# Common Class: blood loss
# Superclasses in Onto1: complications, treatment-related adverse events, measure of concept, blood loss, measure of safety
# Superclasses in Onto2: measure of efficacy, normalized blood loss
# ----------------------------
# Common Class: total cost comparison
# Superclasses in Onto1: measure of concept, measure of costs, total cost comparison
# Superclasses in Onto2: total cost comparison, measure of patient satisfaction
# ----------------------------
# Common Class: objective response rate
# Superclasses in Onto1: measure of concept, measure of efficacy, objective response rate
# Superclasses in Onto2: objective tumor response rate, measure of efficacy
# ----------------------------
# 31

# %% [markdown]
# This ontology has 12 matching classes with the same superclass

# %%
EVALUATION OF CLUSTERED ONTOLOGY WITH GOLD STANDARD CLASSES:

# %%
from owlready2 import *
from rdflib import RDFS

# Load ontologies
onto1 = get_ontology("Gold_standard_Ontology").load()
onto2 = get_ontology("automatic_ontology_3.owl").load()

# Extract classes
classes_onto1 = {str(cls.label[0]).lower(): cls for cls in onto1.classes() if cls.label}
classes_onto2 = {str(cls.label[0]).lower(): cls for cls in onto2.classes() if cls.label}

# Find common classes
common_classes = set()
for label1, cls1 in classes_onto1.items():
    words1 = set(label1.split())
    for label2, cls2 in classes_onto2.items():
        words2 = set(label2.split())
        if words1.issubset(words2):
            if not label1.startswith("measure of"):
                common_classes.add((label1, cls1, cls2))
                break

# Print all common classes and their superclasses
count = 0

for label, cls1, cls2 in common_classes:
    print(f"Common Class: {label}")
    
    superclasses1 = [str(sup.label[0]).lower() for sup in cls1.ancestors() if sup.label]
    superclasses2 = [str(sup.label[0]).lower() for sup in cls2.ancestors() if sup.label]
    count += 1
    
    print(f"Superclasses in Onto1: {', '.join(superclasses1)}")
    print(f"Superclasses in Onto2: {', '.join(superclasses2)}")
    print("----------------------------")

print(count)
# Out:
# Common Class: complications
# Superclasses in Onto1: measure of concept, measure of safety, complications
# Superclasses in Onto2: measure of efficacy, complications
# ----------------------------
# Common Class: long term toxicity
# Superclasses in Onto1: measure of concept, long term toxicity, toxicity, measure of safety
# Superclasses in Onto2: long term toxicity, measure of sexual function
# ----------------------------
# Common Class: overall response rate
# Superclasses in Onto1: overall response rate, measure of efficacy, measure of concept
# Superclasses in Onto2: measure of performance status, overall response rate
# ----------------------------
# Common Class: pain
# Superclasses in Onto1: measure of concept, pain, treatment-related adverse events, complications, measure of safety
# Superclasses in Onto2: heat pain thresholds, measure of quality of life
# ----------------------------
# Common Class: hospital stay
# Superclasses in Onto1: measure of concept, measure of healthcare resource utilization, hospital stay
# Superclasses in Onto2: hospital stay, measure of performance status
# ----------------------------
# Common Class: cost-effectiveness analysis of sms protocol
# Superclasses in Onto1: measure of concept, cost-effectiveness analysis of sms protocol, measure of costs
# Superclasses in Onto2: measure of efficacy, cost-effectiveness analysis of sms protocol
# ----------------------------
# Common Class: time to treatment failure
# Superclasses in Onto1: measure of concept, measure of efficacy, time to treatment failure, measure of safety
# Superclasses in Onto2: measure of performance status, time to treatment failure
# ----------------------------
# Common Class: porto-scanner feasibility
# Superclasses in Onto1: measure of concept, measure of healthcare resource utilization, porto-scanner feasibility
# Superclasses in Onto2: measure of performance status, porto-scanner feasibility
# ----------------------------
# Common Class: cold pain thresholds
# Superclasses in Onto1: measure of concept, pain threshold, measure of tolerability, cold pain thresholds
# Superclasses in Onto2: cold pain thresholds, measure of performance status
# ----------------------------
# Common Class: recurrence-free survival
# Superclasses in Onto1: measure of concept, recurrence-free survival, measure of efficacy, recurrence
# Superclasses in Onto2: measure of performance status, distant recurrence-free survival
# ----------------------------
# Common Class: change in fat free mass
# Superclasses in Onto1: measure of concept, measure of nutritional status, measure of efficacy, change in fat free mass
# Superclasses in Onto2: measure of quality of life, change in fat free mass
# ----------------------------
# Common Class: total cost comparison
# Superclasses in Onto1: total cost comparison, measure of concept, measure of costs
# Superclasses in Onto2: total cost comparison, measure of performance status
# ----------------------------
# Common Class: local recurrences difference
# Superclasses in Onto1: measure of concept, measure of efficacy, recurrence, local recurrences difference
# Superclasses in Onto2: measure of performance status, local recurrences difference
# ----------------------------
# Common Class: disease control rate
# Superclasses in Onto1: measure of concept, disease control rate, measure of efficacy
# Superclasses in Onto2: measure of performance status, disease control rate
# ----------------------------
# Common Class: local recurrence-free survival
# Superclasses in Onto1: measure of concept, recurrence-free survival, measure of efficacy, recurrence, local recurrence-free survival
# Superclasses in Onto2: measure of performance status, local recurrence-free survival
# ----------------------------
# Common Class: postoperative complications
# Superclasses in Onto1: measure of concept, postoperative complications, treatment-related adverse events, complications, measure of safety
# Superclasses in Onto2: measure of performance status, postoperative complications
# ----------------------------
# Common Class: lesion location
# Superclasses in Onto1: measure of concept, lesion location, measure of efficacy
# Superclasses in Onto2: measure of performance status, lesion location
# ----------------------------
# Common Class: adenoma detection rate
# Superclasses in Onto1: adenoma detection rate, measure of efficacy, measure of concept
# Superclasses in Onto2: measure of performance status, adenoma detection rate
# ----------------------------
# Common Class: weight change
# Superclasses in Onto1: measure of concept, measure of safety, weight change
# Superclasses in Onto2: measure of performance status, weight change
# ----------------------------
# Common Class: dose-limiting toxicities
# Superclasses in Onto1: measure of concept, dose-limiting toxicities, measure of safety
# Superclasses in Onto2: measure of performance status, dose-limiting toxicities
# ----------------------------
# Common Class: circulating tumor cells detection
# Superclasses in Onto1: measure of concept, circulating tumor cells detection, measure of efficacy
# Superclasses in Onto2: measure of performance status, circulating tumor cells detection
# ----------------------------
# Common Class: hpv vaccine series start and completion
# Superclasses in Onto1: measure of concept, measure of performance status, hpv vaccine series start and completion
# Superclasses in Onto2: measure of performance status, hpv vaccine series start and completion
# ----------------------------
# Common Class: local polyps recurrence
# Superclasses in Onto1: measure of concept, measure of efficacy, recurrence, local polyps recurrence
# Superclasses in Onto2: measure of performance status, local polyps recurrence
# ----------------------------
# Common Class: pathological response
# Superclasses in Onto1: measure of concept, measure of efficacy, pathological response
# Superclasses in Onto2: measure of efficacy, pathological response rate
# ----------------------------
# Common Class: quality of life questionnaire
# Superclasses in Onto1: measure of concept, quality of life questionnaire, measure of quality of life
# Superclasses in Onto2: measure of efficacy, quality of life questionnaire
# ----------------------------
# Common Class: physical function
# Superclasses in Onto1: measure of concept, physical function, measure of performance status
# Superclasses in Onto2: measure of performance status, physical function
# ----------------------------
# Common Class: recurrence
# Superclasses in Onto1: measure of concept, recurrence, measure of efficacy
# Superclasses in Onto2: measure of performance status, distant recurrence
# ----------------------------
# Common Class: time to pain progression
# Superclasses in Onto1: measure of concept, time to pain progression, pain, treatment-related adverse events, complications, measure of safety
# Superclasses in Onto2: time to pain progression, measure of efficacy
# ----------------------------
# Common Class: injection site reaction
# Superclasses in Onto1: measure of concept, injection site reaction, treatment-related adverse events, complications, measure of safety
# Superclasses in Onto2: measure of performance status, injection site reaction
# ----------------------------
# Common Class: response evaluation criteria in solid tumors
# Superclasses in Onto1: measure of concept, response evaluation criteria in solid tumors, measure of efficacy
# Superclasses in Onto2: response evaluation criteria in solid tumors, measure of performance status
# ----------------------------
# Common Class: npsi score
# Superclasses in Onto1: measure of concept, measure of safety, npsi score
# Superclasses in Onto2: measure of performance status, npsi score
# ----------------------------
# Common Class: protein balance
# Superclasses in Onto1: measure of concept, protein balance, measure of nutritional status
# Superclasses in Onto2: measure of performance status, protein balance
# ----------------------------
# Common Class: heat pain thresholds
# Superclasses in Onto1: measure of concept, pain threshold, heat pain thresholds, measure of tolerability
# Superclasses in Onto2: heat pain thresholds, measure of quality of life
# ----------------------------
# Common Class: local recurrence
# Superclasses in Onto1: measure of concept, measure of efficacy, recurrence, local recurrence
# Superclasses in Onto2: measure of performance status, local polyps recurrence
# ----------------------------
# Common Class: distant recurrence-free survival
# Superclasses in Onto1: measure of concept, recurrence-free survival, measure of efficacy, distant recurrence-free survival, recurrence
# Superclasses in Onto2: measure of performance status, distant recurrence-free survival
# ----------------------------
# Common Class: appendiceal neoplasm incidence
# Superclasses in Onto1: measure of concept, incidence, appendiceal neoplasm incidence, measure of safety
# Superclasses in Onto2: measure of performance status, appendiceal neoplasm incidence
# ----------------------------
# Common Class: lesion size
# Superclasses in Onto1: measure of concept, lesion size, measure of efficacy
# Superclasses in Onto2: measure of performance status, lesion size
# ----------------------------
# Common Class: recommended phase 2 dose
# Superclasses in Onto1: recommended phase 2 dose, measure of concept, measure of safety
# Superclasses in Onto2: measure of performance status, recommended phase 2 dose
# ----------------------------
# Common Class: neurotoxicity
# Superclasses in Onto1: measure of concept, toxicity, measure of safety, neurotoxicity
# Superclasses in Onto2: measure of performance status, neurotoxicity
# ----------------------------
# Common Class: hematologic toxicity
# Superclasses in Onto1: measure of concept, hematologic toxicity, toxicity, measure of safety
# Superclasses in Onto2: measure of performance status, hematologic toxicity
# ----------------------------
# Common Class: treatment response
# Superclasses in Onto1: measure of concept, measure of efficacy, treatment response
# Superclasses in Onto2: measure of performance status, treatment response
# ----------------------------
# Common Class: neutropenia incidence
# Superclasses in Onto1: measure of concept, incidence, neutropenia incidence, measure of safety
# Superclasses in Onto2: neutropenia incidence, measure of performance status
# ----------------------------
# Common Class: anti-drug antibodies incidence
# Superclasses in Onto1: measure of concept, incidence, measure of safety, anti-drug antibodies incidence
# Superclasses in Onto2: measure of sexual function, anti-drug antibodies incidence
# ----------------------------
# Common Class: best overall response
# Superclasses in Onto1: measure of concept, measure of efficacy, best overall response
# Superclasses in Onto2: measure of performance status, best overall response
# ----------------------------
# Common Class: long term health-related quality of life
# Superclasses in Onto1: measure of concept, long term health-related quality of life, measure of quality of life
# Superclasses in Onto2: long term health-related quality of life, measure of quality of life
# ----------------------------
# Common Class: intraoperative blood loss
# Superclasses in Onto1: measure of concept, treatment-related adverse events, complications, intraoperative blood loss, measure of safety
# Superclasses in Onto2: intraoperative blood loss, measure of performance status
# ----------------------------
# Common Class: early late toxicity
# Superclasses in Onto1: measure of concept, early late toxicity, toxicity, measure of safety
# Superclasses in Onto2: measure of performance status, early late toxicity
# ----------------------------
# Common Class: tumor diameter
# Superclasses in Onto1: tumor diameter, measure of efficacy, measure of concept
# Superclasses in Onto2: measure of performance status, tumor diameter
# ----------------------------
# Common Class: progression-free survival
# Superclasses in Onto1: measure of concept, measure of efficacy, progression-free survival
# Superclasses in Onto2: measure of performance status, progression-free survival
# ----------------------------
# Common Class: cost of patient care
# Superclasses in Onto1: measure of concept, cost of patient care, measure of costs
# Superclasses in Onto2: cost of patient care, measure of sexual function
# ----------------------------
# Common Class: adverse event rate
# Superclasses in Onto1: measure of concept, adverse event rate, treatment-related adverse events, complications, measure of safety
# Superclasses in Onto2: measure of efficacy, adverse event rate
# ----------------------------
# Common Class: liver position difference
# Superclasses in Onto1: measure of concept, measure of performance status, liver position difference
# Superclasses in Onto2: measure of performance status, liver position difference
# ----------------------------
# Common Class: radiomics
# Superclasses in Onto1: measure of concept, measure of efficacy, radiomics
# Superclasses in Onto2: measure of efficacy, radiomics
# ----------------------------
# Common Class: postoperative pain
# Superclasses in Onto1: measure of concept, postoperative pain, treatment-related adverse events, complications, measure of safety
# Superclasses in Onto2: measure of performance status, postoperative pain
# ----------------------------
# Common Class: severe adverse event
# Superclasses in Onto1: measure of concept, treatment-related adverse events, complications, severe adverse event, measure of safety
# Superclasses in Onto2: measure of efficacy, severe adverse event
# ----------------------------
# Common Class: area under curve
# Superclasses in Onto1: measure of concept, measure of performance status, area under curve
# Superclasses in Onto2: area under curve, measure of quality of life
# ----------------------------
# Common Class: maximum concentration
# Superclasses in Onto1: measure of concept, measure of healthcare resource utilization, maximum concentration
# Superclasses in Onto2: measure of performance status, maximum concentration
# ----------------------------
# Common Class: surgical site infection
# Superclasses in Onto1: measure of concept, surgical site infection, treatment-related adverse events, complications, measure of safety
# Superclasses in Onto2: measure of performance status, surgical site infection
# ----------------------------
# Common Class: tumor growth rate
# Superclasses in Onto1: measure of concept, measure of efficacy, tumor growth rate
# Superclasses in Onto2: measure of performance status, tumor growth rate
# ----------------------------
# Common Class: change in daily steps
# Superclasses in Onto1: measure of concept, measure of performance status, change in daily steps
# Superclasses in Onto2: measure of performance status, change in daily steps
# ----------------------------
# Common Class: late toxicity
# Superclasses in Onto1: measure of concept, late toxicity, toxicity, measure of safety
# Superclasses in Onto2: measure of performance status, early late toxicity
# ----------------------------
# Common Class: state-trait anxiety inventory
# Superclasses in Onto1: measure of concept, state-trait anxiety inventory, measure of quality of life
# Superclasses in Onto2: measure of efficacy, state-trait anxiety inventory
# ----------------------------
# Common Class: pain threshold
# Superclasses in Onto1: measure of concept, measure of tolerability, pain threshold
# Superclasses in Onto2: measure of efficacy, pain threshold
# ----------------------------
# Common Class: mortality
# Superclasses in Onto1: measure of concept, mortality, measure of efficacy, measure of safety
# Superclasses in Onto2: measure of performance status, mortality
# ----------------------------
# Common Class: duration of response
# Superclasses in Onto1: measure of concept, measure of efficacy, duration of response
# Superclasses in Onto2: measure of performance status, duration of response
# ----------------------------
# Common Class: blood hormone level
# Superclasses in Onto1: measure of concept, measure of safety, blood hormone level
# Superclasses in Onto2: blood hormone level, measure of efficacy
# ----------------------------
# Common Class: ct versus porto-scanner
# Superclasses in Onto1: measure of concept, measure of healthcare resource utilization, ct versus porto-scanner
# Superclasses in Onto2: measure of performance status, ct versus porto-scanner
# ----------------------------
# Common Class: distant recurrence
# Superclasses in Onto1: measure of concept, measure of efficacy, distant recurrence, recurrence
# Superclasses in Onto2: measure of performance status, distant recurrence
# ----------------------------
# Common Class: acute toxicity
# Superclasses in Onto1: measure of concept, acute toxicity, toxicity, measure of safety
# Superclasses in Onto2: measure of efficacy, acute toxicity
# ----------------------------
# Common Class: surgical complications
# Superclasses in Onto1: measure of concept, treatment-related adverse events, complications, surgical complications, measure of safety
# Superclasses in Onto2: surgical complications, measure of performance status
# ----------------------------
# Common Class: terminal elimination half-life
# Superclasses in Onto1: terminal elimination half-life, measure of healthcare resource utilization, measure of concept
# Superclasses in Onto2: measure of performance status, terminal elimination half-life
# ----------------------------
# Common Class: k-ras mutation
# Superclasses in Onto1: measure of concept, k-ras mutation, measure of safety
# Superclasses in Onto2: measure of performance status, k-ras mutation
# ----------------------------
# Common Class: readmission
# Superclasses in Onto1: measure of concept, measure of healthcare resource utilization, readmission
# Superclasses in Onto2: measure of efficacy, readmission
# ----------------------------
# Common Class: radiographic response
# Superclasses in Onto1: radiographic response, measure of efficacy, measure of concept
# Superclasses in Onto2: measure of efficacy, radiographic response
# ----------------------------
# Common Class: hospital anxiety and depression scale
# Superclasses in Onto1: measure of concept, hospital anxiety and depression scale, measure of quality of life
# Superclasses in Onto2: hospital anxiety and depression scale, measure of efficacy
# ----------------------------
# Common Class: mr image findings
# Superclasses in Onto1: measure of concept, mr image findings, measure of efficacy, radiomics
# Superclasses in Onto2: measure of performance status, mr image findings
# ----------------------------
# Common Class: decrease of tumor size
# Superclasses in Onto1: measure of concept, decrease of tumor size, measure of performance status
# Superclasses in Onto2: measure of performance status, decrease of tumor size
# ----------------------------
# Common Class: frequence of positive ctdna
# Superclasses in Onto1: frequence of positive ctdna, measure of efficacy, measure of concept
# Superclasses in Onto2: measure of performance status, frequence of positive ctdna
# ----------------------------
# Common Class: overall survival rate
# Superclasses in Onto1: measure of concept, overall survival rate, measure of efficacy
# Superclasses in Onto2: measure of performance status, overall survival rate
# ----------------------------
# Common Class: treatment-related adverse events
# Superclasses in Onto1: measure of concept, treatment-related adverse events, complications, measure of safety
# Superclasses in Onto2: measure of efficacy, treatment-related adverse events
# ----------------------------
# Common Class: toxicity
# Superclasses in Onto1: measure of concept, measure of safety, toxicity
# Superclasses in Onto2: measure of efficacy, toxicity
# ----------------------------
# Common Class: clinical benefit rate
# Superclasses in Onto1: measure of concept, measure of efficacy, clinical benefit rate
# Superclasses in Onto2: clinical benefit rate, measure of sexual function
# ----------------------------
# Common Class: blood loss
# Superclasses in Onto1: measure of concept, treatment-related adverse events, complications, measure of safety, blood loss
# Superclasses in Onto2: measure of performance status, blood loss
# ----------------------------
# Common Class: overall survival
# Superclasses in Onto1: measure of concept, measure of efficacy, overall survival
# Superclasses in Onto2: measure of performance status, overall survival
# ----------------------------
# Common Class: perioperative morbidity
# Superclasses in Onto1: perioperative morbidity, measure of concept, measure of performance status
# Superclasses in Onto2: measure of efficacy, perioperative morbidity
# ----------------------------
# Common Class: dose limiting toxicity
# Superclasses in Onto1: measure of concept, toxicity, dose limiting toxicity, measure of safety
# Superclasses in Onto2: measure of performance status, dose limiting toxicity
# ----------------------------
# Common Class: morbidity
# Superclasses in Onto1: morbidity, measure of concept, measure of performance status
# Superclasses in Onto2: measure of efficacy, perioperative morbidity
# ----------------------------
# Common Class: time to progression
# Superclasses in Onto1: measure of concept, time to progression, measure of efficacy
# Superclasses in Onto2: time to pain progression, measure of efficacy
# ----------------------------
# Common Class: inflammatory response
# Superclasses in Onto1: measure of concept, inflammatory response, measure of efficacy
# Superclasses in Onto2: measure of efficacy, inflammatory response
# ----------------------------
# Common Class: cardiac toxicity
# Superclasses in Onto1: measure of concept, cardiac toxicity, toxicity, measure of safety
# Superclasses in Onto2: measure of performance status, cardiac toxicity
# ----------------------------
# Common Class: nutritional status
# Superclasses in Onto1: measure of concept, nutritional status, measure of nutritional status
# Superclasses in Onto2: measure of nutritional status
# ----------------------------
# Common Class: time to next treatment
# Superclasses in Onto1: measure of concept, measure of safety, time to next treatment
# Superclasses in Onto2: measure of performance status, time to next treatment
# ----------------------------
# Common Class: incidence
# Superclasses in Onto1: measure of concept, measure of safety, incidence
# Superclasses in Onto2: measure of efficacy, incidence
# ----------------------------
# Common Class: tumor response
# Superclasses in Onto1: measure of concept, measure of efficacy, tumor response
# Superclasses in Onto2: measure of performance status, tumor response
# ----------------------------
# Common Class: tmax
# Superclasses in Onto1: measure of concept, measure of healthcare resource utilization, tmax
# Superclasses in Onto2: measure of efficacy, tmax
# ----------------------------
# Common Class: objective response rate
# Superclasses in Onto1: measure of concept, measure of efficacy, objective response rate
# Superclasses in Onto2: measure of performance status, objective response rate
# ----------------------------
# Common Class: maximum tolerated dose
# Superclasses in Onto1: maximum tolerated dose, measure of concept, measure of safety
# Superclasses in Onto2: measure of performance status, maximum tolerated dose
# ----------------------------
# Common Class: surgical morbidity
# Superclasses in Onto1: surgical morbidity, measure of concept, measure of performance status
# Superclasses in Onto2: surgical morbidity, measure of performance status
# ----------------------------
# Common Class: pathological response rate
# Superclasses in Onto1: measure of concept, pathological response rate, measure of efficacy
# Superclasses in Onto2: measure of efficacy, pathological response rate
# ----------------------------
# 99

# %% [markdown]
# This ontology has 14 matching classes with the same superclass.
